# %% [markdown]
# ## Summary functions
#
# ### Dataset
# From Kaggle (https://www.kaggle.com/datasets/zynicide/wine-reviews)
#
# Download the data using Kaggle
# kaggle datasets download -d zynicide/wine-reviews
# Run in the console the above code

# %%
import pandas as pd
import numpy as np

# %%
# 
reviews_d = pd.read_csv('../data/winemag-data-130k-v2.csv', index_col=0)
reviews_d.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# See unique
print(reviews_d.describe())
print(reviews_d.mean())
print(reviews_d.taster_name.value_counts())
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # See unique
#       2 print(reviews_d.describe())
# ----> 3 print(reviews_d.mean())
#       4 print(reviews_d.taster_name.value_counts())
#
# File c:\Users\assse\anaconda3\envs\mod3_wrangling\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# ...
